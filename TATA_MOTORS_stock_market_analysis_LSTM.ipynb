# %% [markdown]
# <a href="https://colab.research.google.com/github/Neermita18/Stock_Market_Analysis/blob/main/TATA_MOTORS_stock_market_analysis_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
import datetime as dt

# %%
df= pd.read_csv('TATAMOTORS.NS.csv')

# %%
df.index=df['Date']

# %%
df
# Out:
#                   Date        Open         High         Low        Close  \
# Date
# 2022-07-01  2022-07-01  410.649994   414.600006  402.299988   412.700012
# 2022-07-04  2022-07-04  411.549988   414.899994  405.000000   408.450012
# 2022-07-05  2022-07-05  415.000000   418.799988  410.200012   412.000000
# 2022-07-06  2022-07-06  414.000000   417.299988  410.649994   416.350006
# 2022-07-07  2022-07-07  419.899994   432.950012  419.299988   430.850006
# ...                ...         ...          ...         ...          ...
# 2024-06-25  2024-06-25  960.000000   962.849976  949.299988   955.000000
# 2024-06-26  2024-06-26  956.000000   962.500000  950.099976   951.849976
# 2024-06-27  2024-06-27  952.500000   974.849976  948.049988   972.099976
# 2024-06-28  2024-06-28  975.000000   998.500000  972.549988   989.750000
# 2024-07-01  2024-07-01  989.750000  1005.500000  985.200012  1002.049988
#
#               Adj Close    Volume
# Date
# 2022-07-01   410.152069  14725989
# ...

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df
# Out:
#                   Open         High         Low        Close    Adj Close  \
# Date
# 2022-07-01  410.649994   414.600006  402.299988   412.700012   410.152069
# 2022-07-04  411.549988   414.899994  405.000000   408.450012   405.928284
# 2022-07-05  415.000000   418.799988  410.200012   412.000000   409.456360
# 2022-07-06  414.000000   417.299988  410.649994   416.350006   413.779510
# 2022-07-07  419.899994   432.950012  419.299988   430.850006   428.190002
# ...                ...          ...         ...          ...          ...
# 2024-06-25  960.000000   962.849976  949.299988   955.000000   955.000000
# 2024-06-26  956.000000   962.500000  950.099976   951.849976   951.849976
# 2024-06-27  952.500000   974.849976  948.049988   972.099976   972.099976
# 2024-06-28  975.000000   998.500000  972.549988   989.750000   989.750000
# 2024-07-01  989.750000  1005.500000  985.200012  1002.049988  1002.049988
#
#               Volume
# Date
# 2022-07-01  14725989
# 2022-07-04  11525133
# ...

# %%
plt.figure(figsize=(15,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=30))
x_dates= [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in df.index.values]
plt.plot(x_dates,df['High'])
plt.plot(x_dates,df['Low'])
plt.legend(['High','Low'])
plt.title('TATA Motors Stock Market Analysis')
plt.xlabel('Date')
plt.ylabel('Price')
plt.gcf().autofmt_xdate()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
